# %% [markdown]
# <a href="https://colab.research.google.com/github/nehagoyal09/Python_-Practice_Journey/blob/main/Day1_practice_ipyn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Python Basic Terms**
# - Python Program = **statements + expresssions + indentation**
# - Syntax (Valid & Invalid)
# - Comments

# %%
print("Hello, Neha! Welcome to Python practice")    # Simple Python program
# Out:
# Hello, Neha! Welcome to Python practice

# %%
print('Neha')
# Out:
# Neha

# %%
name = 'Neha'          #cap(Name),This is error
print('name')          # Always use in 'semicoulmn'
# Out:
# name

# %%
name = 'Neha'
print(name)
# Out:
# Neha

# %%
address = 'Gwalior, Madhya Pradesh'
print(address)
# Out:
# Gwalior, Madhya Pradesh

# %% [markdown]
# ## **Python Data Types, Type Casting & Variables**
# - **Text Type:** str
# - **Numeric Types:** int, float
# - **Sequence Types:** list, tuple, range
# - **Mapping Type:** dict
# - **Set Types:** set
# - **Boolean Type:** True, False

# %%
name = 'Rishika'          # string
age = 23               # int
percent = 90.3         # float
marks = [90, 85]       # list
is_student = True      # boolean

# %%
type(percent)
# Out:
# float

# %%
student1 = ('Rishika', 23, 90.3)            # Tuple method (cannot modify it)
student2 = ['Rishika', 23, 90.3]            # List method (can modify it)
student3 = {'Rishika', 23, 90.3}            # Set method (random output)

# %%
student2
# Out:
# ['Rishika', 23, 90.3]

# %%
print(range(5))
# Out:
# range(0, 5)

# %%
student = {'Name': 'Rishika', 'Age': 23, 'Percent': 90.3}     # Dict. method

# %%
student.keys()
# Out:
# dict_keys(['Name', 'Age', 'Percent'])

# %%
student.values()
# Out:
# dict_values(['Rishika', 23, 90.3])

# %% [markdown]
# **Python Operators**
#  - **Airthmetic:**  +, -, *, /, //, %, **
# - **Assignment:**  =, +=, -=, *=, /=, %=, **=
# - **Comparison:**  ==, !=, <, >, <=, >=
# - **Logical:**  and, or, not
# - **Membership:** in, not in

# %%
x = 5          # used with numeric values to perform common mathematics
y = 8

# print(x+y, x-y, x*y, x/y, x//y, x%y, x**y)

print(x+y, x**y)
# Out:
# 13 390625

# %%
x, y = 5,8       # used to assign values to variables

# print(x=y, x+=y, x-=y, x*=y, x/=y, x%=y, x**=y)

x -= y      # x = x - y
x *= y      # x = x * y

print(x)
# Out:
# -24

# %%
x = 5             # used to cpmpare two values
y = 8

# print( x==y, x!=y, x<y, x>y, x<=y, x>=y)

print(x>y)
# Out:
# False

# %%
x, y = 5, 8        # used to combine conditional statement

# logical (==, !=, <, >, <=, >=)

# print(x and y, x or y, x not y)

#(x<y) or (x!=y)

not((x<y)or (x!=y))
# Out:
# False

# %%
# (==, !=, <, >, <=, >=)    # used to test if a sequence is presented in an object

# print(x in y, x not in y)

x = [1, 2, 3, 4, 5]
y = 6

#y not in x
y in x
# Out:
# False

# %%
y =[1, 2, 3, 4, 5]
x = 4

# x in y
x not in y
# Out:
# False
